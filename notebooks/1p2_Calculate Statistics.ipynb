# %% [markdown]
# # Statistical Analysis of Extracted Text Data
#
# ## 📌 Overview
# This notebook processes previously extracted **xDD text snippets** and computes **word statistics**, including:
# - **Co-occurrence statistics**: Measures how often words appear together.
# - **Entropy and JointEntropy**: Measures the information contained in words and pairs of words.
# - **Mutual Information**: Measures how two words or terms are related.

# %%
# Import core libraries
import os
import sys
import pandas as pd
# !python -m spacy download en_core_web_sm

# Import custom functions
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

# Import the functions for statistics calculations
from nlp_statistics import process_all_terms

# Move the working directory one level up 
os.chdir(os.path.abspath(os.path.join(os.getcwd(), "..")))
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 4.2 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.8 MB 12.8 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 16.2 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 18.8 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 18.3 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## 1. Define Data Directory & Processing Parameters
#
# Extracted text is stored in the `data` folder. We will:
# ✔ Process **each term folder** separately.
# ✔ Compute **co-occurrence & TF-IDF scores**.
# ✔ Store results as CSV files inside each term folder.

# %%
root_folder = r"D:\MSc\data"
n = 1000000  # Number of most frequent words to analyze
total_docs = 16023367  # This number is the total number of documents in xDD at the time of the search.
overwrite = False  # Set to True to force reprocessing of terms previously searched.

# %% [markdown]
# ## 2. Run Statistical Analysis
#
# This step will:
# - **Scan each term folder** for processed text files.
# - **Run calculations in parallel** to improve efficiency.
# - **Save results as CSV files** inside the corresponding term folder.

# %%
process_all_terms(root_folder, n, total_docs, overwrite)
# Out:
# ✅ abyssal plain already processed. Skipping.
# ✅ accretionary already processed. Skipping.
# ✅ accretionary prism already processed. Skipping.
# ✅ accretionary wedge already processed. Skipping.
# ✅ active already processed. Skipping.
# ✅ active margin already processed. Skipping.
# ✅ adakite already processed. Skipping.
# ✅ aegean already processed. Skipping.
# ✅ aeolian already processed. Skipping.
# ✅ affinity already processed. Skipping.
# ✅ age already processed. Skipping.
# ✅ ailik domain already processed. Skipping.
# ✅ aishihik plutonic suite already processed. Skipping.
# ✅ alaska already processed. Skipping.
# ✅ alberta group already processed. Skipping.
# ✅ aleutian already processed. Skipping.
# ✅ alexander terrane already processed. Skipping.
# ✅ algoma-type bif already processed. Skipping.
# ✅ alkaline already processed. Skipping.
# ✅ alkaline intrusion-hosted ree already processed. Skipping.
# ✅ alkaline rock already processed. Skipping.
# ✅ alluvial already processed. Skipping.
# ✅ along already processed. Skipping.
# ✅ also already processed. Skipping.
# ✅ alteration already processed. Skipping.
# ✅ amazonian craton already processed. Skipping.
# ✅ america already processed. Skipping.
# ✅ american already processed. Skipping.
# ✅ amphibole already processed. Skipping.
# ✅ amphibolite already processed. Skipping.
# ✅ amphibolite facies already processed. Skipping.
# ✅ amphitheater group already processed. Skipping.
# ✅ anahim volcanics already processed. Skipping.
# ✅ analcime already processed. Skipping.
# ✅ andalusite already processed. Skipping.
# ✅ andean already processed. Skipping.
# ✅ andesite already processed. Skipping.
# ✅ andesite line already processed. Skipping.
# ✅ angilak already processed. Skipping.
# ✅ anhydrite already processed. Skipping.
# ✅ annual already processed. Skipping.
# ✅ antarctic craton already processed. Skipping.
# ✅ anthropocene already processed. Skipping.
# ✅ anticline already processed. Skipping.
# ✅ antilles already processed. Skipping.
# ✅ apatite already processed. Skipping.
# ✅ apex mountain complex already processed. Skipping.
# ✅ ar-ar dating already processed. Skipping.
# ✅ arc accretion already processed. Skipping.
# ✅ arc complex already processed. Skipping.
# ✅ arc crust already processed. Skipping.
# ✅ arc evolution already processed. Skipping.
# ✅ arc geochemistry already processed. Skipping.
# ✅ arc granodiorite already processed. Skipping.
# ✅ arc lithosphere already processed. Skipping.
# ✅ arc magmatic belt already processed. Skipping.
# ✅ arc magmatism already processed. Skipping.
# ✅ arc mantle already processed. Skipping.
# ✅ arc rifting already processed. Skipping.
# ✅ arc stratigraphy already processed. Skipping.
# ✅ arc tectonics already processed. Skipping.
# ✅ arc terrane already processed. Skipping.
# ✅ arc volcaniclastic already processed. Skipping.
# ✅ arc volcanism already processed. Skipping.
# ✅ arc-basin system already processed. Skipping.
# ✅ arc-continent collision already processed. Skipping.
# ✅ arc-related sediment already processed. Skipping.
# ✅ arc-related volcanism already processed. Skipping.
# ✅ arc-trench gap already processed. Skipping.
# ✅ arc-trench system already processed. Skipping.
# ✅ archean already processed. Skipping.
# ✅ archean lode gold already processed. Skipping.
# ✅ area already processed. Skipping.
# ✅ argillite already processed. Skipping.
# ✅ arkose already processed. Skipping.
# ✅ arsenopyrite already processed. Skipping.
# ✅ ash fall already processed. Skipping.
# ✅ ashcroft formation already processed. Skipping.
# ✅ asitka group already processed. Skipping.
# ✅ aso caldera complex already processed. Skipping.
# ✅ assay already processed. Skipping.
# ✅ assemblage already processed. Skipping.
# ✅ associated already processed. Skipping.
# ✅ aster data already processed. Skipping.
# ✅ asthenosphere-lithosphere interaction already processed. Skipping.
# ✅ atan group already processed. Skipping.
# ✅ atnarko assemblage already processed. Skipping.
# ✅ attwood group already processed. Skipping.
# ✅ au skarn already processed. Skipping.
# ✅ aves ridge volcanics already processed. Skipping.
# ✅ azurite already processed. Skipping.
# ✅ back already processed. Skipping.
# ✅ back-arc already processed. Skipping.
# ✅ back-arc basin already processed. Skipping.
# ✅ badheart formation already processed. Skipping.
# ✅ badshot formation already processed. Skipping.
# ✅ baltic craton already processed. Skipping.
# ✅ banded iron formation already processed. Skipping.
# ✅ barite already processed. Skipping.
# ✅ basal-type uranium already processed. Skipping.
# ✅ basalt already processed. Skipping.
# ✅ basement already processed. Skipping.
# ✅ basin already processed. Skipping.
# ✅ battle range batholith already processed. Skipping.
# ✅ bauxite already processed. Skipping.
# ✅ bauxite deposit already processed. Skipping.
# ✅ bayonne plutonic suite already processed. Skipping.
# ✅ bayonne suite already processed. Skipping.
# ✅ beach sand heavy minerals already processed. Skipping.
# ✅ belt already processed. Skipping.
# ✅ beneath already processed. Skipping.
# ✅ beryl already processed. Skipping.
# ✅ besshi-type vms already processed. Skipping.
# ✅ bif already processed. Skipping.
# ✅ big creek group already processed. Skipping.
# ✅ big salmon complex already processed. Skipping.
# ✅ biostratigraphy already processed. Skipping.
# ✅ biotite already processed. Skipping.
# ✅ black dome complex already processed. Skipping.
# ✅ black shale already processed. Skipping.
# ✅ black shale-hosted already processed. Skipping.
# ✅ black shale-hosted ni-mo already processed. Skipping.
# ✅ black stuart group already processed. Skipping.
# ✅ blairmore group already processed. Skipping.
# ✅ block already processed. Skipping.
# ✅ block model already processed. Skipping.
# ✅ blueschist already processed. Skipping.
# ✅ blueschist facies already processed. Skipping.
# ✅ bonanza group already processed. Skipping.
# ✅ boninite already processed. Skipping.
# ✅ bornite already processed. Skipping.
# ✅ boulder creek group already processed. Skipping.
# ✅ boundary ranges metamorphic suite already processed. Skipping.
# ✅ bowen island group already processed. Skipping.
# ✅ bowser lake already processed. Skipping.
# ✅ bowser lake group already processed. Skipping.
# ✅ bralorne-east liza complex already processed. Skipping.
# ✅ breccia already processed. Skipping.
# ✅ breccia pipe already processed. Skipping.
# ✅ bridge river complex already processed. Skipping.
# ✅ bridge river terrane already processed. Skipping.
# ✅ british already processed. Skipping.
# ✅ brittle deformation already processed. Skipping.
# ✅ broadview formation already processed. Skipping.
# ✅ bruce river group already processed. Skipping.
# ✅ buckinghorse formation already processed. Skipping.
# ✅ bulkley plutonic suite already processed. Skipping.
# ✅ bullhead group already processed. Skipping.
# ✅ burnaby island plutonic suite already processed. Skipping.
# ✅ bushveld-type pge already processed. Skipping.
# ✅ buttle lake group already processed. Skipping.
# ✅ cache already processed. Skipping.
# ✅ cache creek complex already processed. Skipping.
# ✅ cache creek group already processed. Skipping.
# ✅ cache creek terrane already processed. Skipping.
# ✅ cadwallader group already processed. Skipping.
# ✅ caimito formation already processed. Skipping.
# ✅ calabrian arc units already processed. Skipping.
# ✅ calc already processed. Skipping.
# ✅ calc-alkaline series already processed. Skipping.
# ✅ calcarenite already processed. Skipping.
# ✅ calcite already processed. Skipping.
# ✅ caldera already processed. Skipping.
# ✅ cambrian already processed. Skipping.
# ✅ cancrinite already processed. Skipping.
# ✅ carbonate already processed. Skipping.
# ✅ carbonate platform already processed. Skipping.
# ✅ carbonatite already processed. Skipping.
# ✅ carbonatite-hosted ree already processed. Skipping.
# ✅ carboniferous already processed. Skipping.
# ✅ caribbean large igneous province already processed. Skipping.
# ✅ cariboo group already processed. Skipping.
# ✅ carlin-type already processed. Skipping.
# ✅ carlin-type gold already processed. Skipping.
# ✅ carmanah group already processed. Skipping.
# ✅ carnallite already processed. Skipping.
# ✅ cascade already processed. Skipping.
# ✅ cascade arc already processed. Skipping.
# ✅ casma group already processed. Skipping.
# ✅ cassiterite already processed. Skipping.
# ✅ cataclasite already processed. Skipping.
# ✅ cayoosh assemblage already processed. Skipping.
# ✅ celestine already processed. Skipping.
# ✅ cenozoic already processed. Skipping.
# ✅ center already processed. Skipping.
# ✅ central already processed. Skipping.
# ✅ central gneiss complex already processed. Skipping.
# ✅ central mineral belt already processed. Skipping.
# ✅ chabazite already processed. Skipping.
# ✅ chagres formation already processed. Skipping.
# ✅ chalcocite already processed. Skipping.
# ✅ chalcopyrite already processed. Skipping.
# ✅ chalk already processed. Skipping.
# ✅ chapperon group already processed. Skipping.
# ✅ characteristic already processed. Skipping.
# ✅ charlie lake formation already processed. Skipping.
# ✅ chemostratigraphy already processed. Skipping.
# ✅ chert already processed. Skipping.
# ✅ chilcotin group already processed. Skipping.
# ✅ chilliwack group already processed. Skipping.
# ✅ chinches formation already processed. Skipping.
# ✅ chlorite already processed. Skipping.
# ✅ chromite already processed. Skipping.
# ✅ chrysocolla already processed. Skipping.
# ✅ chrysotile already processed. Skipping.
# ✅ chu chua formation already processed. Skipping.
# ✅ chuchi lake succession already processed. Skipping.
# ✅ chuckanut formation already processed. Skipping.
# ✅ chugach terrane already processed. Skipping.
# ✅ churchill province already processed. Skipping.
# ✅ cim guidelines already processed. Skipping.
# ✅ cinder cone already processed. Skipping.
# ✅ cinnabar already processed. Skipping.
# ✅ clastic already processed. Skipping.
# ✅ cleavage already processed. Skipping.
# ✅ coal already processed. Skipping.
# ✅ coast plutonic complex already processed. Skipping.
# ✅ cobaltite already processed. Skipping.
# ✅ colg already processed. Skipping.
# ✅ collision already processed. Skipping.
# ✅ collision zone already processed. Skipping.
# ✅ collisional already processed. Skipping.
# ✅ colluvial already processed. Skipping.
# ✅ columbia already processed. Skipping.
# ✅ complex already processed. Skipping.
# ✅ composition already processed. Skipping.
# ✅ compressional tectonics already processed. Skipping.
# ✅ conglomerate already processed. Skipping.
# ✅ contact metamorphism already processed. Skipping.
# ✅ continental already processed. Skipping.
# ✅ continental arc already processed. Skipping.
# ✅ continental collision already processed. Skipping.
# ✅ continental drift already processed. Skipping.
# ✅ continental rift already processed. Skipping.
# ✅ continental shelf already processed. Skipping.
# ✅ continental slope already processed. Skipping.
# ✅ continental subduction already processed. Skipping.
# ✅ copper mountain plutonic suite already processed. Skipping.
# ✅ cordillera already processed. Skipping.
# ✅ core logging already processed. Skipping.
# ✅ coromandel group already processed. Skipping.
# ✅ corundum already processed. Skipping.
# ✅ coryell plutonic suite already processed. Skipping.
# ✅ covellite already processed. Skipping.
# ✅ coya-machalí formation already processed. Skipping.
# ✅ craton already processed. Skipping.
# ✅ creek already processed. Skipping.
# ✅ cretaceous already processed. Skipping.
# ✅ crooked amphibolite already processed. Skipping.
# ✅ crust already processed. Skipping.
# ✅ crustal already processed. Skipping.
# ✅ crustal thickening already processed. Skipping.
# ✅ crustal thinning already processed. Skipping.
# ✅ cryptocrystalline graphite already processed. Skipping.
# ✅ cu already processed. Skipping.
# ✅ cu skarn already processed. Skipping.
# ✅ custer gneiss already processed. Skipping.
# ✅ cut-off grade already processed. Skipping.
# ✅ cyprus-type vms already processed. Skipping.
# ✅ dacite already processed. Skipping.
# ✅ daonella beds already processed. Skipping.
# ✅ data already processed. Skipping.
# ✅ dean river metamorphic belt already processed. Skipping.
# ✅ deep marine already processed. Skipping.
# ✅ deformation already processed. Skipping.
# ✅ delamination already processed. Skipping.
# ✅ deltaic already processed. Skipping.
# ✅ deltaic system already processed. Skipping.
# ✅ deposit already processed. Skipping.
# ✅ depth already processed. Skipping.
# ✅ descon formation already processed. Skipping.
# ✅ deserters gneiss already processed. Skipping.
# ✅ detachment fault already processed. Skipping.
# ✅ developed already processed. Skipping.
# ✅ devonian already processed. Skipping.
# ✅ dezadeash group already processed. Skipping.
# ✅ diagram already processed. Skipping.
# ✅ diamond drilling already processed. Skipping.
# ✅ diamondiferous already processed. Skipping.
# ✅ diatomite already processed. Skipping.
# ✅ diorite already processed. Skipping.
# ✅ discordance already processed. Skipping.
# ✅ dolomite already processed. Skipping.
# ✅ dolostone already processed. Skipping.
# ✅ dorsey complex already processed. Skipping.
# ✅ drilling already processed. Skipping.
# ✅ dtm already processed. Skipping.
# ✅ duarte complex already processed. Skipping.
# ✅ ductile deformation already processed. Skipping.
# ✅ eagle bay assemblage already processed. Skipping.
# ✅ early already processed. Skipping.
# ✅ early cretaceous already processed. Skipping.
# ✅ early eocene already processed. Skipping.
# ✅ early jurassic already processed. Skipping.
# ✅ early miocene already processed. Skipping.
# ✅ early oligocene already processed. Skipping.
# ✅ early paleocene already processed. Skipping.
# ✅ early pleistocene already processed. Skipping.
# ✅ early pliocene already processed. Skipping.
# ✅ early triassic already processed. Skipping.
# ✅ earn group already processed. Skipping.
# ✅ earth already processed. Skipping.
# ✅ east already processed. Skipping.
# ✅ eastern already processed. Skipping.
# ✅ eclogite already processed. Skipping.
# ✅ eclogite facies already processed. Skipping.
# ✅ ecstall belt already processed. Skipping.
# ✅ element already processed. Skipping.
# ✅ endako batholith already processed. Skipping.
# ✅ endako group already processed. Skipping.
# ✅ endako phase already processed. Skipping.
# ✅ endako subsuite already processed. Skipping.
# ✅ endicott arm assemblage already processed. Skipping.
# ✅ environment already processed. Skipping.
# ✅ eocene already processed. Skipping.
# ✅ eolian already processed. Skipping.
# ✅ epidote already processed. Skipping.
# ✅ epithermal already processed. Skipping.
# ✅ espee formation already processed. Skipping.
# ✅ esr already processed. Skipping.
# ✅ estuarine already processed. Skipping.
# ✅ evaporite already processed. Skipping.
# ✅ evidence already processed. Skipping.
# ✅ evolution already processed. Skipping.
# ✅ example already processed. Skipping.
# ✅ extensional tectonics already processed. Skipping.
# ✅ extrusive rock already processed. Skipping.
# ✅ fairholme group already processed. Skipping.
# ✅ farellones formation already processed. Skipping.
# ✅ fault already processed. Skipping.
# ✅ fe already processed. Skipping.
# ✅ fe skarn already processed. Skipping.
# ✅ feldspar already processed. Skipping.
# ✅ felsic already processed. Skipping.
# ✅ felsic rock already processed. Skipping.
# ✅ fennell assemblage already processed. Skipping.
# ✅ fennell formation already processed. Skipping.
# ✅ field already processed. Skipping.
# ✅ figure already processed. Skipping.
# ✅ firvale suite already processed. Skipping.
# ✅ fission track already processed. Skipping.
# ✅ fission track dating already processed. Skipping.
# ✅ fissure eruption already processed. Skipping.
# ✅ flake graphite already processed. Skipping.
# ✅ flood basalt already processed. Skipping.
# ✅ flow already processed. Skipping.
# ✅ fluid inclusion already processed. Skipping.
# ✅ fluorite already processed. Skipping.
# ✅ fluvial already processed. Skipping.
# ✅ flux melting already processed. Skipping.
# ✅ fold already processed. Skipping.
# ✅ fold-and-thrust belt already processed. Skipping.
# ✅ folding already processed. Skipping.
# ✅ foliation already processed. Skipping.
# ✅ forearc already processed. Skipping.
# ✅ forearc basin already processed. Skipping.
# ✅ forearc deformation already processed. Skipping.
# ✅ foreland basin already processed. Skipping.
# ✅ form already processed. Skipping.
# ✅ formation already processed. Skipping.
# ✅ fort st. john group already processed. Skipping.
# ✅ fracture already processed. Skipping.
# ✅ francois lake plutonic suite already processed. Skipping.
# ✅ francois lake suite already processed. Skipping.
# ✅ fraser lake suite already processed. Skipping.
# ✅ gabbro already processed. Skipping.
# ✅ galena already processed. Skipping.
# ✅ gambier group already processed. Skipping.
# ✅ gamsby complex already processed. Skipping.
# ✅ garibaldi group already processed. Skipping.
# ✅ garnet already processed. Skipping.
# ✅ geochemical already processed. Skipping.
# ✅ geochemical anomaly already processed. Skipping.
# ✅ geochemical survey already processed. Skipping.
# ✅ geochemistry already processed. Skipping.
# ✅ geological already processed. Skipping.
# ✅ geological mapping already processed. Skipping.
# ✅ geology already processed. Skipping.
# ✅ geophysical survey already processed. Skipping.
# ✅ geophysics already processed. Skipping.
# ✅ georeferencing already processed. Skipping.
# ✅ geospatial analysis already processed. Skipping.
# ✅ geostatistics already processed. Skipping.
# ✅ ghost rocks formation already processed. Skipping.
# ✅ gis in geology already processed. Skipping.
# ✅ glauconite already processed. Skipping.
# ✅ glenannan phase already processed. Skipping.
# ✅ glenannan subsuite already processed. Skipping.
# ✅ gneiss already processed. Skipping.
# ✅ goethite already processed. Skipping.
# ✅ gog group already processed. Skipping.
# ✅ gondwana already processed. Skipping.
# ✅ gossan already processed. Skipping.
# ✅ gouge already processed. Skipping.
# ✅ grade already processed. Skipping.
# ✅ grand forks gneiss already processed. Skipping.
# ✅ granite already processed. Skipping.
# ✅ granitoids already processed. Skipping.
# ✅ granulite already processed. Skipping.
# ✅ granulite facies already processed. Skipping.
# ✅ graphite already processed. Skipping.
# ✅ gravina assemblage already processed. Skipping.
# ✅ gravina belt volcanics already processed. Skipping.
# ✅ gravity anomaly already processed. Skipping.
# ✅ green tuff belt already processed. Skipping.
# ✅ greenschist already processed. Skipping.
# ✅ greenschist facies already processed. Skipping.
# ✅ greisen already processed. Skipping.
# ✅ greywacke already processed. Skipping.
# ✅ group already processed. Skipping.
# ✅ guichon creek batholith already processed. Skipping.
# ✅ guichon suite already processed. Skipping.
# ✅ gypsum already processed. Skipping.
# ✅ gypsum rock already processed. Skipping.
# ✅ hadean already processed. Skipping.
# ✅ halite already processed. Skipping.
# ✅ halite rock already processed. Skipping.
# ✅ hamill group already processed. Skipping.
# ✅ harper ranch group already processed. Skipping.
# ✅ hazelton group already processed. Skipping.
# ✅ hellenic already processed. Skipping.
# ✅ hematite already processed. Skipping.
# ✅ henry creek formation already processed. Skipping.
# ✅ herradura group already processed. Skipping.
# ✅ heulandite already processed. Skipping.
# ✅ high already processed. Skipping.
# ✅ high-pressure metamorphism already processed. Skipping.
# ✅ high-sulfidation epithermal already processed. Skipping.
# ✅ holocene already processed. Skipping.
# ✅ hornfels already processed. Skipping.
# ✅ horsethief creek group already processed. Skipping.
# ✅ hot spot already processed. Skipping.
# ✅ hot spring au-ag already processed. Skipping.
# ✅ hotailuh batholith already processed. Skipping.
# ✅ hotspot already processed. Skipping.
# ✅ however already processed. Skipping.
# ✅ hozameen complex already processed. Skipping.
# ✅ hydrothermal already processed. Skipping.
# ✅ hyland group already processed. Skipping.
# ✅ hyperspectral imaging already processed. Skipping.
# ✅ hypothermal already processed. Skipping.
# ✅ iblean plateau already processed. Skipping.
# ✅ igneous already processed. Skipping.
# ✅ igneous intrusion already processed. Skipping.
# ✅ ignimbrite already processed. Skipping.
# ✅ illite already processed. Skipping.
# ✅ ilmenite already processed. Skipping.
# ✅ implication already processed. Skipping.
# ✅ indian craton already processed. Skipping.
# ✅ ingenika group already processed. Skipping.
# ✅ intermediate-sulfidation epithermal already processed. Skipping.
# ✅ interpreted already processed. Skipping.
# ✅ intra already processed. Skipping.
# ✅ intra-cratonic basin already processed. Skipping.
# ✅ intracontinental volcanism already processed. Skipping.
# ✅ intrusion-related gold already processed. Skipping.
# ✅ intrusive rock already processed. Skipping.
# ✅ inverse distance weighting already processed. Skipping.
# ✅ ioa already processed. Skipping.
# ✅ iocg already processed. Skipping.
# ✅ irish-type already processed. Skipping.
# ✅ iron mask batholith already processed. Skipping.
# ✅ ironstone already processed. Skipping.
# ✅ island already processed. Skipping.
# ✅ island arc already processed. Skipping.
# ✅ island plutonic suite already processed. Skipping.
# ✅ isostatic rebound already processed. Skipping.
# ✅ isotopic already processed. Skipping.
# ✅ izu already processed. Skipping.
# ✅ jackass mountain group already processed. Skipping.
# ✅ joint set already processed. Skipping.
# ✅ jorc already processed. Skipping.
# ✅ jowett formation already processed. Skipping.
# ✅ jurassic already processed. Skipping.
# ✅ k-ar dating already processed. Skipping.
# ✅ kaapvaal craton already processed. Skipping.
# ✅ kamloops group already processed. Skipping.
# ✅ kano plutonic suite already processed. Skipping.
# ✅ kaolinite already processed. Skipping.
# ✅ karmutsen formation already processed. Skipping.
# ✅ karst already processed. Skipping.
# ✅ kasalka group already processed. Skipping.
# ✅ kaslo group already processed. Skipping.
# ✅ kaza group already processed. Skipping.
# ✅ kechika group already processed. Skipping.
# ✅ kenorland already processed. Skipping.
# ✅ kerogen already processed. Skipping.
# ✅ kimberlite already processed. Skipping.
# ✅ kimberlite-hosted diamond already processed. Skipping.
# ✅ kindle formation already processed. Skipping.
# ✅ kingsvale group already processed. Skipping.
# ✅ klinkit group already processed. Skipping.
# ✅ km already processed. Skipping.
# ✅ knob hill group already processed. Skipping.
# ✅ komatiite already processed. Skipping.
# ✅ kootenay group already processed. Skipping.
# ✅ kriging already processed. Skipping.
# ✅ kunga group already processed. Skipping.
# ✅ kuroko-type vms already processed. Skipping.
# ✅ kuskanax batholith already processed. Skipping.
# ✅ kutcho assemblage already processed. Skipping.
# ✅ kyanite already processed. Skipping.
# ✅ kyuquot group already processed. Skipping.
# ✅ laberge group already processed. Skipping.
# ✅ lacustrine already processed. Skipping.
# ✅ ladner group already processed. Skipping.
# ✅ ladybird intrusion already processed. Skipping.
# ✅ lahar already processed. Skipping.
# ✅ lamproite already processed. Skipping.
# ✅ lamproite-hosted diamond already processed. Skipping.
# ✅ landsat already processed. Skipping.
# ✅ lardeau group already processed. Skipping.
# ✅ large igneous province already processed. Skipping.
# ✅ late already processed. Skipping.
# ✅ late cretaceous already processed. Skipping.
# ✅ late eocene already processed. Skipping.
# ✅ late jurassic already processed. Skipping.
# ✅ late miocene already processed. Skipping.
# ✅ late oligocene already processed. Skipping.
# ✅ late paleocene already processed. Skipping.
# ✅ late pleistocene already processed. Skipping.
# ✅ late pliocene already processed. Skipping.
# ✅ late triassic already processed. Skipping.
# ✅ laterite already processed. Skipping.
# ✅ lateritic bauxite already processed. Skipping.
# ✅ lateritic ni-co already processed. Skipping.
# ✅ lateritic nickel already processed. Skipping.
# ✅ laurasia already processed. Skipping.
# ✅ lava already processed. Skipping.
# ✅ lava flow already processed. Skipping.
# ✅ lay range assemblage already processed. Skipping.
# ✅ lazurite already processed. Skipping.
# ✅ lct pegmatite already processed. Skipping.
# ✅ leech river complex already processed. Skipping.
# ✅ lepidolite already processed. Skipping.
# ✅ lesser already processed. Skipping.
# ✅ leucite already processed. Skipping.
# ✅ lidar already processed. Skipping.
# ✅ lignite-hosted uranium already processed. Skipping.
# ✅ limestone already processed. Skipping.
# ✅ limonite already processed. Skipping.
# ✅ lineation already processed. Skipping.
# ✅ lip already processed. Skipping.
# ✅ lithology already processed. Skipping.
# ✅ lithosphere already processed. Skipping.
# ✅ lithospheric flexure already processed. Skipping.
# ✅ lithostratigraphy already processed. Skipping.
# ✅ location already processed. Skipping.
# ✅ lode gold already processed. Skipping.
# ✅ low-sulfidation epithermal already processed. Skipping.
# ✅ lower already processed. Skipping.
# ✅ lower road river group already processed. Skipping.
# ✅ lu-hf already processed. Skipping.
# ✅ luzon already processed. Skipping.
# ✅ löllingite already processed. Skipping.
# ✅ mafic already processed. Skipping.
# ✅ mafic rock already processed. Skipping.
# ✅ magma already processed. Skipping.
# ✅ magma chamber already processed. Skipping.
# ✅ magma plume already processed. Skipping.
# ✅ magmatic already processed. Skipping.
# ✅ magmatism already processed. Skipping.
# ✅ magnetic anomaly already processed. Skipping.
# ✅ magnetite already processed. Skipping.
# ✅ magnetite-apatite deposits already processed. Skipping.
# ✅ main already processed. Skipping.
# ✅ major already processed. Skipping.
# ✅ malachite already processed. Skipping.
# ✅ manganese nodules already processed. Skipping.
# ✅ mantle already processed. Skipping.
# ✅ mantle convection already processed. Skipping.
# ✅ mantle downwelling already processed. Skipping.
# ✅ mantle hotspot already processed. Skipping.
# ✅ mantle upwelling already processed. Skipping.
# ✅ mantle wedge already processed. Skipping.
# ✅ marble already processed. Skipping.
# ✅ marcasite already processed. Skipping.
# ✅ margin already processed. Skipping.
# ✅ mariana already processed. Skipping.
# ✅ marine already processed. Skipping.
# ✅ marl already processed. Skipping.
# ✅ masset formation already processed. Skipping.
# ✅ maude group already processed. Skipping.
# ✅ mcdame group already processed. Skipping.
# ✅ mckay group already processed. Skipping.
# ✅ mclaughlin ridge formation already processed. Skipping.
# ✅ melting already processed. Skipping.
# ✅ meratus complex already processed. Skipping.
# ✅ mesothermal already processed. Skipping.
# ✅ mesothermal gold already processed. Skipping.
# ✅ mesozoic already processed. Skipping.
# ✅ metaconglomerate already processed. Skipping.
# ✅ metamorphic already processed. Skipping.
# ✅ metamorphic core complex already processed. Skipping.
# ✅ metamorphism already processed. Skipping.
# ✅ metapelite already processed. Skipping.
# ✅ metaquartzite already processed. Skipping.
# ✅ metasandstone already processed. Skipping.
# ✅ metasomatism already processed. Skipping.
# ✅ metchosin igneous complex already processed. Skipping.
# ✅ mica creek succession already processed. Skipping.
# ✅ microcontinent already processed. Skipping.
# ✅ mid already processed. Skipping.
# ✅ mid-ocean ridge already processed. Skipping.
# ✅ middle already processed. Skipping.
# ✅ middle eocene already processed. Skipping.
# ✅ middle jurassic already processed. Skipping.
# ✅ middle miocene already processed. Skipping.
# ✅ middle pleistocene already processed. Skipping.
# ✅ middle triassic already processed. Skipping.
# ✅ miette group already processed. Skipping.
# ✅ migmatite already processed. Skipping.
# ✅ milford formation already processed. Skipping.
# ✅ millerite already processed. Skipping.
# ✅ mineralization already processed. Skipping.
# ✅ mineralogy already processed. Skipping.
# ✅ minnes group already processed. Skipping.
# ✅ miocene already processed. Skipping.
# ✅ misinchinka group already processed. Skipping.
# ✅ mississippi valley-type already processed. Skipping.
# ✅ mississippian already processed. Skipping.
# ✅ mn already processed. Skipping.
# ✅ mo already processed. Skipping.
# ✅ model already processed. Skipping.
# ✅ modern already processed. Skipping.
# ✅ molybdenite already processed. Skipping.
# ✅ monashee complex already processed. Skipping.
# ✅ monazite already processed. Skipping.
# ✅ monocline already processed. Skipping.
# ✅ montmorillonite already processed. Skipping.
# ✅ morb already processed. Skipping.
# ✅ moresby group already processed. Skipping.
# ✅ mount brock volcanics already processed. Skipping.
# ✅ mount edziza volcanic complex already processed. Skipping.
# ✅ mount ida assemblage already processed. Skipping.
# ✅ mount lytton complex already processed. Skipping.
# ✅ mountain already processed. Skipping.
# ✅ mountain building already processed. Skipping.
# ✅ mt already processed. Skipping.
# ✅ mudstone already processed. Skipping.
# ✅ multispectral analysis already processed. Skipping.
# ✅ muncho-mcconnell formation already processed. Skipping.
# ✅ mural formation already processed. Skipping.
# ✅ muscovite already processed. Skipping.
# ✅ mvt already processed. Skipping.
# ✅ mylonite already processed. Skipping.
# ✅ nanaimo group already processed. Skipping.
# ✅ nappe already processed. Skipping.
# ✅ native element already processed. Skipping.
# ✅ natrolite already processed. Skipping.
# ✅ nature already processed. Skipping.
# ✅ nazcha formation already processed. Skipping.
# ✅ nb already processed. Skipping.
# ✅ nd isotope ratios already processed. Skipping.
# ✅ near already processed. Skipping.
# ✅ nelson batholith already processed. Skipping.
# ✅ neogene already processed. Skipping.
# ✅ nepheline already processed. Skipping.
# ✅ new already processed. Skipping.
# ✅ new guinea mobile belt already processed. Skipping.
# ✅ ni already processed. Skipping.
# ✅ ni 43-101 already processed. Skipping.
# ✅ niccolite already processed. Skipping.
# ✅ nicola group already processed. Skipping.
# ✅ nina creek group already processed. Skipping.
# ✅ normal fault already processed. Skipping.
# ✅ north already processed. Skipping.
# ✅ north china craton already processed. Skipping.
# ✅ northern already processed. Skipping.
# ✅ nuna already processed. Skipping.
# ✅ obsidian already processed. Skipping.
# ✅ ocean already processed. Skipping.
# ✅ oceanic subduction already processed. Skipping.
# ✅ oceanic trench already processed. Skipping.
# ✅ oil shale already processed. Skipping.
# ✅ okanagan batholith already processed. Skipping.
# ✅ okhotsk-chukotka volcanic belt already processed. Skipping.
# ✅ oligocene already processed. Skipping.
# ✅ olivine already processed. Skipping.
# ✅ one already processed. Skipping.
# ✅ oolite already processed. Skipping.
# ✅ oolitic limestone already processed. Skipping.
# ✅ ootsa group already processed. Skipping.
# ✅ ootsa lake group already processed. Skipping.
# ✅ ophiolite already processed. Skipping.
# ✅ ophiolite complex already processed. Skipping.
# ✅ ophiolite-hosted chromite already processed. Skipping.
# ✅ ordovician already processed. Skipping.
# ✅ ore deposit already processed. Skipping.
# ✅ ore reserve already processed. Skipping.
# ✅ origin already processed. Skipping.
# ✅ orogen already processed. Skipping.
# ✅ orogenic already processed. Skipping.
# ✅ orogenic belt already processed. Skipping.
# ✅ orogenic gold already processed. Skipping.
# ✅ orogenic zone already processed. Skipping.
# ✅ orogeny already processed. Skipping.
# ✅ orpiment already processed. Skipping.
# ✅ overlies already processed. Skipping.
# ✅ oxide already processed. Skipping.
# ✅ oxygen fugacity already processed. Skipping.
# ✅ pacific already processed. Skipping.
# ✅ pacific rim complex already processed. Skipping.
# ✅ palaeozoic already processed. Skipping.
# ✅ paleocene already processed. Skipping.
# ✅ paleogene already processed. Skipping.
# ✅ paleosol already processed. Skipping.
# ✅ paleozoic already processed. Skipping.
# ✅ pangea already processed. Skipping.
# ✅ pannotia already processed. Skipping.
# ✅ papuan ultramafic belt already processed. Skipping.
# ✅ part already processed. Skipping.
# ✅ pasayten group already processed. Skipping.
# ✅ passive margin already processed. Skipping.
# ✅ pathfinder element already processed. Skipping.
# ✅ pb already processed. Skipping.
# ✅ pb isotope ratios already processed. Skipping.
# ✅ pb-pb already processed. Skipping.
# ✅ pearce already processed. Skipping.
# ✅ peat already processed. Skipping.
# ✅ pegmatite already processed. Skipping.
# ✅ pennsylvanian already processed. Skipping.
# ✅ penticton group already processed. Skipping.
# ✅ pentlandite already processed. Skipping.
# ✅ peridotite already processed. Skipping.
# ✅ peril formation already processed. Skipping.
# ✅ permian already processed. Skipping.
# ✅ petalite already processed. Skipping.
# ✅ petrogenesis already processed. Skipping.
# ✅ petrology already processed. Skipping.
# ✅ pge already processed. Skipping.
# ✅ pgm already processed. Skipping.
# ✅ phanerozoic already processed. Skipping.
# ✅ phonolite already processed. Skipping.
# ✅ phosphate rock already processed. Skipping.
# ✅ phosphate rock deposits already processed. Skipping.
# ✅ phyllite already processed. Skipping.
# ✅ pilbara craton already processed. Skipping.
# ✅ pillow lava already processed. Skipping.
# ✅ placer already processed. Skipping.
# ✅ placer gold already processed. Skipping.
# ✅ placer ree already processed. Skipping.
# ✅ placer tin already processed. Skipping.
# ✅ planet already processed. Skipping.
# ✅ plate already processed. Skipping.
# ✅ plate convergence already processed. Skipping.
# ✅ plate divergence already processed. Skipping.
# ✅ plate transcurrence already processed. Skipping.
# ✅ platform already processed. Skipping.
# ✅ pleistocene already processed. Skipping.
# ✅ pliocene already processed. Skipping.
# ✅ plot already processed. Skipping.
# ✅ plutonic arc already processed. Skipping.
# ✅ plutonic rock already processed. Skipping.
# ✅ polaris ultramafic complex already processed. Skipping.
# ✅ pollucite already processed. Skipping.
# ✅ porphyry already processed. Skipping.
# ✅ porphyry au already processed. Skipping.
# ✅ porphyry cu already processed. Skipping.
# ✅ porphyry cu-au already processed. Skipping.
# ✅ porphyry cu-mo already processed. Skipping.
# ✅ porphyry mo already processed. Skipping.
# ✅ porphyry sn-w already processed. Skipping.
# ✅ ppb already processed. Skipping.
# ✅ ppm already processed. Skipping.
# ✅ prehnite already processed. Skipping.
# ✅ present already processed. Skipping.
# ✅ princeton group already processed. Skipping.
# ✅ process already processed. Skipping.
# ✅ prograde metamorphism already processed. Skipping.
# ✅ prospectivity already processed. Skipping.
# ✅ proterozoic already processed. Skipping.
# ✅ psilomelane already processed. Skipping.
# ✅ pull-apart basin already processed. Skipping.
# ✅ pumice already processed. Skipping.
# ✅ purcell supergroup already processed. Skipping.
# ✅ pyrite already processed. Skipping.
# ✅ pyroclastic already processed. Skipping.
# ✅ pyroclastic rock already processed. Skipping.
# ✅ pyrolusite already processed. Skipping.
# ✅ pyroxene already processed. Skipping.
# ✅ qgis already processed. Skipping.
# ✅ quartz already processed. Skipping.
# ✅ quartz-carbonate vein gold already processed. Skipping.
# ✅ quartzite already processed. Skipping.
# ✅ quaternary already processed. Skipping.
# ✅ queen charlotte group already processed. Skipping.
# ✅ quesnel lake gneiss already processed. Skipping.
# ✅ quesnel terrane already processed. Skipping.
# ✅ radiometric dating already processed. Skipping.
# ✅ radiometric survey already processed. Skipping.
# ✅ ram creek group already processed. Skipping.
# ✅ range already processed. Skipping.
# ✅ rapid river tectonite already processed. Skipping.
# ✅ ratio already processed. Skipping.
# ✅ rb-sr already processed. Skipping.
# ✅ rb-sr dating already processed. Skipping.
# ✅ rc drilling already processed. Skipping.
# ✅ re-os dating already processed. Skipping.
# ✅ realgar already processed. Skipping.
# ✅ red mountain stock already processed. Skipping.
# ✅ redox boundary already processed. Skipping.
# ✅ ree already processed. Skipping.
# ✅ ree deposit already processed. Skipping.
# ✅ reef already processed. Skipping.
# ✅ region already processed. Skipping.
# ✅ regional metamorphism already processed. Skipping.
# ✅ related already processed. Skipping.
# ✅ relay mountain group already processed. Skipping.
# ✅ remnant already processed. Skipping.
# ✅ remote sensing already processed. Skipping.
# ✅ reservoir rock already processed. Skipping.
# ✅ resistivity survey already processed. Skipping.
# ✅ resource estimation already processed. Skipping.
# ✅ result already processed. Skipping.
# ✅ retrograde metamorphism already processed. Skipping.
# ✅ review already processed. Skipping.
# ✅ rhodochrosite already processed. Skipping.
# ✅ rhyolite already processed. Skipping.
# ✅ ridge already processed. Skipping.
# ✅ ridge push already processed. Skipping.
# ✅ rift basin already processed. Skipping.
# ✅ rift zone already processed. Skipping.
# ✅ rift-related volcanism already processed. Skipping.
# ✅ road river group already processed. Skipping.
# ✅ rock already processed. Skipping.
# ✅ rock chip sampling already processed. Skipping.
# ✅ rocky mountain group already processed. Skipping.
# ✅ rodinia already processed. Skipping.
# ✅ roll-front uranium already processed. Skipping.
# ✅ rossland group already processed. Skipping.
# ✅ rundle group already processed. Skipping.
# ✅ rutile already processed. Skipping.
# ✅ salmon river formation already processed. Skipping.
# ✅ sample already processed. Skipping.
# ✅ san christoval plutonic suite already processed. Skipping.
# ✅ sandpile group already processed. Skipping.
# ✅ sandstone already processed. Skipping.
# ✅ sandstone-hosted u already processed. Skipping.
# ✅ sandstone-hosted uranium already processed. Skipping.
# ✅ sar radar already processed. Skipping.
#
# 📊 Processing: sask craton
# Building word list for 'sask craton': 100%|██████████████████████████████████████| 894/894 [00:03<00:00, 251.22 docs/s]
# ✅ Saved co-occurrence statistics to D:\MSc\data\sask craton\sask craton_cooccurrence_stats.csv
# 📊 Saved corpus stats for sask craton to D:\MSc\data\sask craton\sask craton_corpus_stats.csv
# ✅ scapolite already processed. Skipping.
# ✅ scheelite already processed. Skipping.
# ✅ schist already processed. Skipping.
# ✅ scoria already processed. Skipping.
# ✅ sea already processed. Skipping.
# ✅ sedex already processed. Skipping.
# ✅ sedex pb-zn already processed. Skipping.
# ✅ sediment already processed. Skipping.
# ✅ sediment-hosted cu already processed. Skipping.
# ✅ sediment-hosted vms already processed. Skipping.
# ✅ sedimentary already processed. Skipping.
# ✅ sedimentology already processed. Skipping.
# ✅ seismic survey already processed. Skipping.
# ✅ sequence stratigraphy already processed. Skipping.
# ✅ serpentine already processed. Skipping.
# ✅ serpentinite already processed. Skipping.
# ✅ setting already processed. Skipping.
# ✅ shale already processed. Skipping.
# ✅ shear zone already processed. Skipping.
# ✅ shield already processed. Skipping.
# ✅ shield volcano already processed. Skipping.
# ✅ shonektaw formation already processed. Skipping.
# ✅ show already processed. Skipping.
# ✅ shulaps ultramafic complex already processed. Skipping.
# ✅ shuswap assemblage already processed. Skipping.
# ✅ siberian craton already processed. Skipping.
# ✅ sicker group already processed. Skipping.
# ✅ sifton formation already processed. Skipping.
# ✅ signature already processed. Skipping.
# ✅ silicate already processed. Skipping.
# ✅ sillimanite already processed. Skipping.
# ✅ siltstone already processed. Skipping.
# ✅ silurian already processed. Skipping.
# ✅ similar already processed. Skipping.
# ✅ similkameen batholith already processed. Skipping.
# ✅ sitlika assemblage already processed. Skipping.
# ✅ skarn already processed. Skipping.
# ✅ skarn fe-cu-au already processed. Skipping.
# ✅ skeena group already processed. Skipping.
# ✅ skutterudite already processed. Skipping.
# ✅ slab already processed. Skipping.
# ✅ slab dehydration already processed. Skipping.
# ✅ slab melting already processed. Skipping.
# ✅ slab pull already processed. Skipping.
# ✅ slab rollback already processed. Skipping.
# ✅ slate already processed. Skipping.
# ✅ slate belt gold already processed. Skipping.
# ✅ slave craton already processed. Skipping.
# ✅ slickenside already processed. Skipping.
# ✅ slide already processed. Skipping.
# ✅ slide mountain complex already processed. Skipping.
# ✅ slide mountain group already processed. Skipping.
# ✅ slide mountain terrane already processed. Skipping.
# ✅ slip already processed. Skipping.
# ✅ slocan group already processed. Skipping.
# ✅ sloko group already processed. Skipping.
# ✅ sm-nd already processed. Skipping.
# ✅ sm-nd dating already processed. Skipping.
# ✅ smithsonite already processed. Skipping.
# ✅ smokey group already processed. Skipping.
# ✅ sn already processed. Skipping.
# ✅ snowshoe group already processed. Skipping.
# ✅ soapstone already processed. Skipping.
# ✅ sodalite already processed. Skipping.
# ✅ soil sampling already processed. Skipping.
# ✅ source already processed. Skipping.
# ✅ source rock already processed. Skipping.
# ✅ south already processed. Skipping.
# ✅ southern already processed. Skipping.
# ✅ spectral mineralogy already processed. Skipping.
# ✅ spences bridge group already processed. Skipping.
# ✅ sphalerite already processed. Skipping.
# ✅ spike peak intrusive suite already processed. Skipping.
# ✅ spinel already processed. Skipping.
# ✅ spodumene already processed. Skipping.
# ✅ spray river group already processed. Skipping.
# ✅ spreading already processed. Skipping.
# ✅ spreading center already processed. Skipping.
# ✅ sr isotope ratios already processed. Skipping.
# ✅ stable isotopes already processed. Skipping.
# ✅ stag lake plutonic suite already processed. Skipping.
# ✅ staurolite already processed. Skipping.
# ✅ stelkuz formation already processed. Skipping.
# ✅ stern creek plutonic suite already processed. Skipping.
# ✅ stikine assemblage already processed. Skipping.
# ✅ stikine plutonic suite already processed. Skipping.
# ✅ stikine terrane already processed. Skipping.
# ✅ stikine volcanic belt already processed. Skipping.
# ✅ stikinia already processed. Skipping.
# ✅ stilbite already processed. Skipping.
# ✅ stockwork already processed. Skipping.
# ✅ stoddart group already processed. Skipping.
# ✅ stratigraphy already processed. Skipping.
# ✅ stratovolcano already processed. Skipping.
# ✅ stream sediment sampling already processed. Skipping.
# ✅ stress regime already processed. Skipping.
# ✅ strike-slip basin already processed. Skipping.
# ✅ strike-slip fault already processed. Skipping.
# ✅ strike-slip fault zone already processed. Skipping.
# ✅ structural geology already processed. Skipping.
# ✅ structure already processed. Skipping.
# ✅ study already processed. Skipping.
# ✅ stuhini group already processed. Skipping.
# ✅ subducted already processed. Skipping.
# ✅ subduction already processed. Skipping.
# ✅ subduction erosion already processed. Skipping.
# ✅ subduction metamorphism already processed. Skipping.
# ✅ subduction zone already processed. Skipping.
# ✅ submarine already processed. Skipping.
# ✅ sulfide already processed. Skipping.
# ✅ sully formation already processed. Skipping.
# ✅ supercontinent already processed. Skipping.
# ✅ supercontinent cycle already processed. Skipping.
# ✅ supercraton already processed. Skipping.
# ✅ supergene already processed. Skipping.
# ✅ supergene enrichment cu already processed. Skipping.
# ✅ superior craton already processed. Skipping.
# ✅ superior-type bif already processed. Skipping.
# ✅ surprise lake plutonic suite already processed. Skipping.
# ✅ sustut group already processed. Skipping.
# ✅ suture zone already processed. Skipping.
# ✅ swift river group already processed. Skipping.
# ✅ sylvia formation already processed. Skipping.
# ✅ sylvite already processed. Skipping.
# ✅ syn already processed. Skipping.
# ✅ syncline already processed. Skipping.
# ✅ system already processed. Skipping.
# ✅ são francisco craton already processed. Skipping.
# ✅ ta already processed. Skipping.
# ✅ tacaza group already processed. Skipping.
# ✅ takla group already processed. Skipping.
# ✅ takomkane batholith already processed. Skipping.
# ✅ talc already processed. Skipping.
# ✅ talkeetna formation already processed. Skipping.
# ✅ tanzanian craton already processed. Skipping.
# ✅ target generation already processed. Skipping.
# ✅ tarlac formation already processed. Skipping.
# ✅ tatla lake metamorphic complex already processed. Skipping.
# ✅ tats group already processed. Skipping.
# ✅ taupo volcanic zone already processed. Skipping.
# ✅ taylor creek group already processed. Skipping.
# ✅ tchur already processed. Skipping.
# ✅ tdm already processed. Skipping.
# ✅ tectonic already processed. Skipping.
# ✅ tectonic mélange already processed. Skipping.
# ✅ tectonics already processed. Skipping.
# ✅ telkwa formation already processed. Skipping.
# ✅ terrane already processed. Skipping.
# ✅ texas creek plutonic suite already processed. Skipping.
# ✅ thermochronology already processed. Skipping.
# ✅ tholeiitic series already processed. Skipping.
# ✅ thomsonite already processed. Skipping.
# ✅ three sisters plutonic suite already processed. Skipping.
# ✅ thrust already processed. Skipping.
# ✅ thrust belt already processed. Skipping.
# ✅ thrust fault already processed. Skipping.
# ✅ tillite already processed. Skipping.
# ✅ time already processed. Skipping.
# ✅ tma already processed. Skipping.
# ✅ toad formation already processed. Skipping.
# ✅ toodoggone volcanics already processed. Skipping.
# ✅ topaz already processed. Skipping.
# ✅ topley intrusive suite already processed. Skipping.
# ✅ tourmaline already processed. Skipping.
# ✅ tpg already processed. Skipping.
# ✅ trace already processed. Skipping.
# ✅ trachyte already processed. Skipping.
# ✅ tracy arm assemblage already processed. Skipping.
# ✅ transform boundary already processed. Skipping.
# ✅ transpressional tectonics already processed. Skipping.
# ✅ travertine already processed. Skipping.
# ✅ trench already processed. Skipping.
# ✅ trenching already processed. Skipping.
# ✅ triassic already processed. Skipping.
# ✅ tsaydiz formation already processed. Skipping.
# ✅ tuff already processed. Skipping.
# ✅ turbidite already processed. Skipping.
# ✅ turquoise already processed. Skipping.
# ✅ twin creek assemblage already processed. Skipping.
# ✅ two already processed. Skipping.
# ✅ tyaughton group already processed. Skipping.
# ✅ type already processed. Skipping.
# ✅ typical already processed. Skipping.
# ✅ ultrahigh-pressure metamorphism already processed. Skipping.
# ✅ ultramafic already processed. Skipping.
# ✅ ultramafic rock already processed. Skipping.
# ✅ unconformably overlies already processed. Skipping.
# ✅ unconformity already processed. Skipping.
# ✅ unconformity uranium already processed. Skipping.
# ✅ unconformity-related uranium already processed. Skipping.
# ✅ underlain by already processed. Skipping.
# ✅ unit already processed. Skipping.
# ✅ upper already processed. Skipping.
# ✅ uraninite already processed. Skipping.
# ✅ uranium already processed. Skipping.
# ✅ vaalbara already processed. Skipping.
# ✅ vab already processed. Skipping.
# ✅ vag already processed. Skipping.
# ✅ valdez group already processed. Skipping.
# ✅ vanadinite already processed. Skipping.
# ✅ vancouver group already processed. Skipping.
# ✅ vanderhoof metamorphic complex already processed. Skipping.
# ✅ variogram already processed. Skipping.
# ✅ vein already processed. Skipping.
# ✅ vein graphite already processed. Skipping.
# ✅ vms already processed. Skipping.
# ✅ volcanic already processed. Skipping.
# ✅ volcanic arc already processed. Skipping.
# ✅ volcanic breccia already processed. Skipping.
# ✅ volcanic chain already processed. Skipping.
# ✅ volcanic front already processed. Skipping.
# ✅ volcanic province already processed. Skipping.
# ✅ volcanic-hosted uranium already processed. Skipping.
# ✅ volcaniclastic already processed. Skipping.
# ✅ volcanism already processed. Skipping.
# ✅ volcano already processed. Skipping.
# ✅ w skarn already processed. Skipping.
# ✅ weathering profile already processed. Skipping.
# ✅ wedge already processed. Skipping.
# ✅ wells gray volcanics already processed. Skipping.
# ✅ west already processed. Skipping.
# ✅ west african craton already processed. Skipping.
# ✅ westcoast crystalline complex already processed. Skipping.
# ✅ western already processed. Skipping.
# ✅ whatshan batholith already processed. Skipping.
# ✅ wilson cycle already processed. Skipping.
# ✅ windermere supergroup already processed. Skipping.
# ✅ wineglass assemblage already processed. Skipping.
# ✅ within already processed. Skipping.
# ✅ wolframite already processed. Skipping.
# ✅ wolverine metamorphic complex already processed. Skipping.
# ✅ wolverine range plutonic suite already processed. Skipping.
# ✅ wpg already processed. Skipping.
# ✅ wrangellia terrane already processed. Skipping.
# ✅ wt% already processed. Skipping.
# ✅ wulfenite already processed. Skipping.
# ✅ xenotime already processed. Skipping.
# ✅ yakoun group already processed. Skipping.
# ✅ yakutat group already processed. Skipping.
# ✅ yilgarn craton already processed. Skipping.
# ✅ ymir group already processed. Skipping.
# ✅ zambales ophiolite complex already processed. Skipping.
# ✅ zeolite already processed. Skipping.
# ✅ zeolite facies already processed. Skipping.
# ✅ zeolite rock already processed. Skipping.
# ✅ zircon already processed. Skipping.
# ✅ zn already processed. Skipping.
# ✅ zn-pb skarn already processed. Skipping.
# ✅ zone already processed. Skipping.
# ✅ zr already processed. Skipping.
# ✅ zymoetz group already processed. Skipping.
# ✅ ɛhf already processed. Skipping.
# ✅ ɛnd already processed. Skipping.

# %% [markdown]
# ## 3. Review Extracted Statistics
#
# Once processing is complete, each term folder will contain:
# ✔ `term_cooccurrence_stats.csv` → Co-occurrence frequencies.
# ✔ `term_tfidf.csv` → Term importance scores.
#
# Let's now preview some of these results.

# %%
# Define the root directory where data is stored
root_folder = os.path.join(os.getcwd(), r"D:\MSc\data")

term_folder = os.path.join(root_folder, "volcanic arc")  # Example term
cooc_file = os.path.join(term_folder, "volcanic arc_cooccurrence_stats.csv")

if os.path.exists(cooc_file):
    df_cooc = pd.read_csv(cooc_file)
    print(f"✅ Successfully loaded {len(df_cooc)} co-occurrence records from {cooc_file}")
    display(df_cooc.head(10))
else:
    print("⚠ No co-occurrence data found. Ensure the processing step was completed successfully.")
# Out:
# ✅ Successfully loaded 19765 co-occurrence records from D:\MSc\data\volcanic arc\volcanic arc_cooccurrence_stats.csv
#          word_1       word_2  count     prob_w1w2
# 0  volcanic arc      granite   3981  5.743173e-08
# 1  volcanic arc         rock   3527  5.088212e-08
# 2  volcanic arc       active   2613  3.769633e-08
# 3  volcanic arc   subduction   2538  3.661435e-08
# 4  volcanic arc       basalt   2399  3.460907e-08
# 5  volcanic arc        basin   2367  3.414743e-08
# 6  volcanic arc        plate   2320  3.346938e-08
# 7  volcanic arc      central   2283  3.293560e-08
# 8  volcanic arc  continental   2267  3.270478e-08
# 9  volcanic arc       within   2218  3.199788e-08

# %% [markdown]
# ### 🔹 What Are Co-Occurrence Statistics?
#
# Co-occurrence statistics help identify **which words frequently appear together**. This allows us to:
# - **Understand context**: Words that co-occur frequently may represent key relationships.
# - **Improve keyword extraction**: Helps refine NLP models by identifying dominant term associations.
#
# ---

# %% [markdown]
# ## 4. Next Steps
#
# Now that we have:
# ✔ Extracted data (`1_xdd_data_extraction.ipynb`).
# ✔ Processed word statistics (`2_calculate_statistics.ipynb`).
#
# 📌 **Next Notebook: `3_DDB Import and Analysis.ipynb`**
# - Import statistics into **postgreSQL**.
# - Update further calculations such as **mutual information**.
# - Visualize and explore **semantic trends in geoscience literature**.
#
# ---
